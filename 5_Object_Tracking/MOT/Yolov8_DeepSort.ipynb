# %%
#https://github.com/mikel-brostrom/boxmot

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
os.chdir('/content/drive/MyDrive/mot')

# %%
# !git clone https://github.com/mikel-brostrom/yolov8_tracking.git
#!pip install -r requirements.txt
# !pip install boxmot
# Out:
# fatal: destination path 'yolov8_tracking' already exists and is not an empty directory.
# ERROR: Could not open requirements file: [Errno 2] No such file or directory: 'requirements.txt'
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.0/178.0 kB 8.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 5.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 50.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.3/18.3 MB 119.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.8/44.8 kB 4.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 88.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.6/61.6 kB 5.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 63.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 5.2 MB/s eta 0:00:00
# ...

# %%
 # !boxmot track --yolo-model yolov8n.pt --tracking-method deepocsort --source download.mp4 --project custom_output --save
# Out:
# /usr/local/lib/python3.11/dist-packages/boxmot/utils/checks.py:5: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources
# 2025-06-07 15:54:35.037 | ERROR    | boxmot.utils.checks:check_packages:39 - The 'ultralytics' distribution was not found and is required by the application
# 2025-06-07 15:54:35.038 | WARNING  | boxmot.utils.checks:install_packages:47 -
# Missing packages: ultralytics
# Attempting installation...
# Using Python 3.11.13 environment at: /usr
# Resolved 51 packages in 317ms
# ⠙ Preparing packages... (0/2)
# ⠙ Preparing packages... (0/2)
# ⠙ Preparing packages... (0/2)
# ⠙ Preparing packages... (0/2)
# ⠙ Preparing packages... (0/2)
# ⠙ Preparing packages... (0/2)
# ⠙ Preparing packages... (0/2)
# ⠙ Preparing packages... (0/2)
# ⠙ Preparing packages... (0/2)
# ...
